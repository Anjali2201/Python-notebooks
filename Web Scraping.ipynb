# %% [markdown]
# # Web scraping
# Web scraping, also called web data mining or web harvesting, is the process of constructing an agent which can extract, parse, download and organize useful information from the web automatically. In other words, we can say that instead of manually saving the data from websites, the web scraping software will automatically load and extract data from multiple websites as per our requirement.

# %% [markdown]
# # Web Scraping Lib/Process
# request library: It is a Python library which is used to read the web page data from the URL of the corresponding page.
#
# BeautifulSoup: It is a class which is used to beautify the HTML code structure so that the user can read it to get an idea about HTML code syntax.
#
# The web scraping process can be divided into four major parts:
#
# Reading: HTML page read and upload
#
# Parsing: To beautify the HTML code in an understandable format
#
# Extraction: Extraction of data from the web page
#
# Transformation: Converting the information into the required format, e.g., CSV

# %% [markdown]
# ### Topic Covered: Web Scrapping & Beautiful Soup

# %% [markdown]
# Suppose you want to buy a phone and want to compare the features and prices of the Samsung
# phones available on Flipkart and Amazon.

# %% [markdown]
# #### Example 1: Scraping Data from Flipkart

# %% [markdown]
# In order to do that, let's apply the understanding of web scraping on the Flipkart website to fetch
# prices and technical specifications data from the web page. This Flipkart link
# <br>
# <a>https://www.flipkart.com/search?q=samsung+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=samsung+mobiles%7CMobiles&requestId=18944876-a6ef-44c0-ac67-d31d7b11a548&as-backfill=on</a>
# <br>
# contains information about some features of Samsung phones, including technical specifications,
# prices, discounts and rating, etc.

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
url=  "https://www.flipkart.com/search?q=samsung+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=samsung+mobiles%7CMobiles&requestId=18944876-a6ef-44c0-ac67-d31d7b11a548&as-backfill=on"
client= uReq(url)
page_html= client.read()
client.close()

# %%
client

# %%
page_soup= soup(page_html)

# %%
containers= page_soup.findAll("div", {"class": "_13oc-S"})

# %%
print(len(containers))
# Out:
# 24

# %%
import re
filename= "Samsung.csv"
f= open(filename, "w",encoding="UTF-8")

headers= "Mobile_Name,Price,Ratings,Links,Technical_Specifications\n"
f.write(headers)

for container in containers:
    name= container.findAll('div',{"class":"_4rR01T"})
    Name= name[0].text
    Name = re.sub(r"[\(\)]",'',Name)
    Name=Name.replace(",","")
    link=container.findAll("a")
    Link=link[0].attrs['href']
    price= container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
    Price=price[0].text
    Price=Price.replace(",","")
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=container.findAll("div", {"class": "_3LWZlK"})
    Ratings=rating[0].text
    specification =container.findAll("ul", {"class": "_1xgFaf"})
    Specification=specification[0].text
    f.write(Name + ","+ Price + "," + Ratings + ","+Link+"," + Specification+"\n")

  
f.close()

# %%
import pandas as pd
df = pd.read_csv("Samsung.csv", encoding="utf-8")
df
# Out:
#                                      Mobile_Name  Price  Ratings  \
# 0            SAMSUNG Galaxy F22 Denim Blue 64 GB  11999      4.3
# 1           SAMSUNG Galaxy F22 Denim Blue 128 GB  13999      4.3
# 2          SAMSUNG Galaxy F22 Denim Black 128 GB  13999      4.3
# 3           SAMSUNG Galaxy M32 Light Blue 128 GB  14799      4.3
# 4           SAMSUNG Galaxy F22 Denim Black 64 GB  11999      4.3
GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 4   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....
# 5   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 7   6 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Displ...
# 8   4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 9   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 10  NA ROM5.08 cm (2 inch) NA Display800 mAh Batte...
# 11  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...
# 12  8 MB RAM | 0 GB ROM | Expandable Upto 16 GB5.0...
# 13  NA ROM5.08 cm (2 inch) NA Display800 mAh Batte...
# 14  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...
# 15  0.53 RAM | NA KB ROM | Expandable Upto 16 GB5....
# 16  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 17  Expandable Upto 16 GB5.08 cm (2 inch) QVGA Dis...
# 18  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 19  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...
# 20  153 MB RAM | 153 MB ROM3.81 cm (1.5 inch) Disp...
# 21  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 22  6 GB RAM | 128 GB ROM16.51 cm (6.5 inch) Displ...
# 23  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %% [markdown]
# Get the phone details with min and max price of the phone.

# %%
max=pd.DataFrame(df[df.Price == df.Price.max()])
min=pd.DataFrame(df[df.Price == df.Price.min()])

# %%
max
# Out:
#                                  Mobile_Name  Price  Ratings  \
# 5     SAMSUNG Galaxy F23 5G Aqua Blue 128 GB  16999      4.1
# 6  SAMSUNG Galaxy F23 5G Copper Blush 128 GB  16999      4.1
# 9  SAMSUNG Galaxy F23 5G Forest Green 128 GB  16999      4.1
#
#                                                Links  \
# 5  /samsung-galaxy-f23-5g-aqua-blue-128-gb/p/itme...
# 6  /samsung-galaxy-f23-5g-copper-blush-128-gb/p/i...
# 9  /samsung-galaxy-f23-5g-forest-green-128-gb/p/i...
#
#                             Technical_Specifications
# 5  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 6  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# 9  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %%
min
# Out:
#         Mobile_Name  Price  Ratings  \
# 20  SAMSUNG GURU GT   1497      4.1
#
#                                                 Links  \
# 20  /samsung-guru-gt/p/itm15efc9f269431?pid=MOBG9Z...
#
#                              Technical_Specifications
# 20  153 MB RAM | 153 MB ROM3.81 cm (1.5 inch) Disp...

# %% [markdown]
# ### Example 2
# In order to do that, let's apply the understanding of web scraping on the Amazon website to fetch
# prices and technical specifications data from the web page. This Amazon link
# <a>
# https://www.amazon.in/s?k=samsung&rh=n%3A1389401031&ref=nb_sb_noss </a>
# contains information about some features of Samsung phones, including technical specifications,
# prices, discounts and rating, etc.

# %%
url1=  "https://www.amazon.in/s?k=samsung&rh=n%3A1389401031&ref=nb_sb_noss"
client1= uReq(url1)
page_html1= client1.read()
client1.close()

# %%
client1

# %%
page= soup(page_html1)

# %%
box=page.find_all("div",{"class":"sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"})

# %%
len(box)
# Out:
# 24

# %%
import re
filename= "Samsung2.csv"
f= open(filename, "w",encoding="UTF-8")

headers= "Mobile_Name,Price,Ratings,Links,Discounts\n"
f.write(headers)

for phone in box:
    name= phone.findAll("span",{"class":"a-size-medium a-color-base a-text-normal"})
    Name= name[0].text
    Name=Name.replace(",","")
    link=phone.findAll("a")
    Link=link[0].attrs['href']
    price= phone.findAll("span", {"class": "a-offscreen"})
    Price=price[0].text
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=phone.findAll("span", {"class": "a-icon-alt"})
    Ratings=rating[0].text
    discount =phone.findAll("span", {"class": None})
    Discount=discount[4].text
    print(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
    f.write(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
    # print(Name + "," + Link + ","+ Price +"\n")
f.close()
# Out:
# Samsung Galaxy M12 (Blue4GB RAM 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate,10499,4.1 out of 5 stars,/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ,(19% off)
#
# Samsung Galaxy M12 (Black4GB RAM 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate,10499,4.1 out of 5 stars,/Samsung-Galaxy-M12-Storage-Processor/dp/B08XJCMGL7,(19% off)
#
# Samsung Galaxy M32 (Black 4GB RAM 64GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera,14999,4.1 out of 5 stars,/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VDG9QV,(12% off)
#
# Samsung Galaxy M32 (Light Blue 6GB RAM 128GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera,16999,4.1 out of 5 stars,/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VDR283,(11% off)
#
# Samsung Galaxy M32 5G (Sky Blue 8GB RAM 128GB Storage) | Dimensity 720 Processor | 5000mAh Battery| Knox Security,22999,4.1 out of 5 stars,/Samsung-Galaxy-Blue-128GB-Storage/dp/B09CGJFY5N,(12% off)
#
# Samsung Galaxy M33 5G (Deep Ocean Blue 6GB 128GB Storage) | Travel Adapter to be Purchased Separately,17999,3.8 out of 5 stars,/Samsung-Storage-Adapter-Purchased-Separately/dp/B09TWDYSWQ,(28% off)
#
# Samsung Galaxy S20 FE 5G (Cloud Navy 8GB RAM 128GB Storage) with No Cost EMI & Additional Exchange Offers,39990,4.4 out of 5 stars,/Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB57558,(47% off)
#
# Samsung Galaxy A13 Blue 4GB RAM 64GB Storage with No Cost EMI/Additional Exchange Offers (SM-A135FLBGINS),14999,3.5 out of 5 stars,/Samsung-Storage-Additional-Exchange-SM-A135FLBGINS/dp/B09VK3G99F,(19% off)
#
# Samsung Galaxy M21 2021 Edition (Arctic Blue 4GB RAM 64GB Storage) | FHD+ sAMOLED | 6 Months Free Screen Replacement for Prime (SM-M215GLBDINS),12999,4.2 out of 5 stars,/Samsung-Storage-sAMOLED-Replacement-SM-M215GLBDINS/dp/B098NGDNMT,(10% off)
#
# Samsung Galaxy A52s 5G (Black 8GB RAM 128GB Storage) Without Offers,29700,4.2 out of 5 stars,/Samsung-Galaxy-Storage-Without-Offers/dp/B09D86QT7R,(29% off)
#
# Samsung Galaxy A23 Blue 6GB RAM 128GB Storage with No Cost EMI/Additional Exchange Offers,18499,3.9 out of 5 stars,/Samsung-Galaxy-Storage-Additional-Exchange/dp/B09VK5D8KW,(23% off)
#
# Samsung Galaxy M33 5G (Deep Ocean Blue 8GB 128GB Storage) | Travel Adapter to be Purchased Separately,19499,3.8 out of 5 stars,/Samsung-Storage-Adapter-Purchased-Separately/dp/B09TWH8YHM,(25% off)
#
# Samsung Galaxy A23 Light Blue 6GB RAM 128GB Storage Without Offers,18200,3.9 out of 5 stars,/Test-Test_Withoffer_53/dp/B09DJVQ77C,(24% off)
#
# Samsung Original EHS64 Wired in Ear Earphones with Mic Black,429,4.2 out of 5 stars,/Samsung-Original-EHS64AVFBECINU-Hands-Free-Remote/dp/B01F262EUU,(4% off)
#
# Samsung Galaxy M32 5G (Slate Black 6GB RAM 128GB Storage) | Dimensity 720 Processor | 5000mAh Battery| Knox Security,20999,4.1 out of 5 stars,/Samsung-Galaxy-Slate-Black-Storage/dp/B09CGLRLYM,(13% off)
#
# Samsung Galaxy M32 (Black 6GB RAM 128GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera,16999,4.1 out of 5 stars,/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VD6RQG,(11% off)
#
# Samsung Guru 1215 (GT-E1215 Black),1499,3.8 out of 5 stars,/Samsung-Guru-1215-GT-E1215-Black/dp/B09MTVDZCL,(29% off)
#
# Samsung Galaxy M53 5G (Mystique Green 6GB 128GB Storage) | Travel Adapter to be Purchased Separately,26499,3.8 out of 5 stars,/Samsung-Mystique-Storage-Purchased-Separately/dp/B09XJ48QPR,(20% off)
#
# Samsung Galaxy A22 5G (Gray 6GB RAM 128GB Storage) Without Offer,15991,4.0 out of 5 stars,/Samsung-Galaxy-128GB-Storage-Without/dp/B08ZJSZ2KV,(29% off)
#
# Samsung EHS64 EHS64AVFWECINU Hands-Free with Remote Note (White),419,4.2 out of 5 stars,/Samsung-Original-EHS64AVFWECINU-Stereo-Headset/dp/B01F25X6RQ,(16% off)
#
# Samsung Galaxy A23 Peach 8GB RAM 128GB Storage with No Cost EMI/Additional Exchange Offers,19999,3.9 out of 5 stars,/Samsung-Galaxy-Storage-Additional-Exchange/dp/B09VK8G4XZ,(18% off)
#
# Samsung Galaxy Watch4 Bluetooth(44mm Black Compatible with Android only),15289,4.2 out of 5 stars,/Samsung-Galaxy-Bluetooth-Compatible-Android/dp/B09DG9VNWB,(49% off)
#
# Samsung Guru Music 2 315 (GT-B315 Black) (SM-B315EZKDINS),1999,4.2 out of 5 stars,/Samsung-Guru-Music-GT-B315-Black/dp/B09MKT9ZYM,(20% off)
#
# Samsung Galaxy Buds Pro | 99% Noise Cancellation Wireless Charging (18) Hours Playtime | Black,7990,4.2 out of 5 stars,/Samsung-Galaxy-Ear-Buds-Black/dp/B08SKDXKZF,(56% off)

# %%
import pandas as pd
df2 = pd.read_csv("Samsung2.csv", encoding="utf-8")
df2
# Out:
#                                           Mobile_Name  Price  \
# 0   Samsung Galaxy M12 (Blue4GB RAM 64GB Storage) ...  10499
# 1   Samsung Galaxy M12 (Black4GB RAM 64GB Storage)...  10499
# 2   Samsung Galaxy M32 (Black 4GB RAM 64GB | FHD+ ...  14999
# 17  3.8 out of 5 stars  /Samsung-Mystique-Storage-Purchased-Separately...
# 18  4.0 out of 5 stars  /Samsung-Galaxy-128GB-Storage-Without/dp/B08ZJ...
# 19  4.2 out of 5 stars  /Samsung-Original-EHS64AVFWECINU-Stereo-Headse...
# 20  3.9 out of 5 stars  /Samsung-Galaxy-Storage-Additional-Exchange/dp...
# 21  4.2 out of 5 stars  /Samsung-Galaxy-Bluetooth-Compatible-Android/d...
# 22  4.2 out of 5 stars    /Samsung-Guru-Music-GT-B315-Black/dp/B09MKT9ZYM
# 23  4.2 out of 5 stars       /Samsung-Galaxy-Ear-Buds-Black/dp/B08SKDXKZF
#
#     Discounts
# 0   (19% off)
# 1   (19% off)
# 2   (12% off)
# 3   (11% off)
# 4   (12% off)
# 5   (28% off)
# 6   (47% off)
# 7   (19% off)
# 8   (10% off)
# 9   (29% off)
# 10  (23% off)
# 11  (25% off)
# 12  (24% off)
# 13   (4% off)
# 14  (13% off)
# 15  (11% off)
# 16  (29% off)
# 17  (20% off)
# 18  (29% off)
# 19  (16% off)
# 20  (18% off)
# 21  (49% off)
# 22  (20% off)
# 23  (56% off)

# %%
df2_max=pd.DataFrame(df[df2.Price == df2.Price.max()])
df2_min=pd.DataFrame(df[df2.Price == df2.Price.min()])

# %%
df2_max
# Out:
#                                  Mobile_Name  Price  Ratings  \
# 6  SAMSUNG Galaxy F23 5G Copper Blush 128 GB  16999      4.1
#
#                                                Links  \
# 6  /samsung-galaxy-f23-5g-copper-blush-128-gb/p/i...
#
#                             Technical_Specifications
# 6  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %%
df2_min
# Out:
#                        Mobile_Name  Price  Ratings  \
# 19  SAMSUNG Galaxy M12 White 64 GB  10965      4.2
#
#                                                 Links  \
# 19  /samsung-galaxy-m12-white-64-gb/p/itmfc7abd828...
#
#                              Technical_Specifications
# 19  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...

# %% [markdown]
# ## Get the price of Samsung Galaxy F12 available with price comparison in Amazon & flipkart

# %%
#flipkart
df3=pd.DataFrame(df[df.Mobile_Name == "SAMSUNG Galaxy M12 Black 64 GB"])

# %%
df3
# Out:
#                        Mobile_Name  Price  Ratings  \
# 14  SAMSUNG Galaxy M12 Black 64 GB  11192      4.2
#
#                                                 Links  \
# 14  /samsung-galaxy-m12-black-64-gb/p/itm425898eed...
#
#                              Technical_Specifications
# 14  4 GB RAM | 64 GB ROM16.51 cm (6.5 inch) Displa...

# %%
#amazon
df4=pd.DataFrame(df2[df2.Mobile_Name == "Samsung Galaxy M12 (Black4GB RAM 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate"])

# %%
df4
# Out:
#                                          Mobile_Name  Price  \
# 1  Samsung Galaxy M12 (Black4GB RAM 64GB Storage)...  10499
#
#               Ratings                                              Links  \
# 1  4.1 out of 5 stars  /Samsung-Galaxy-M12-Storage-Processor/dp/B08XJ...
#
#    Discounts
# 1  (19% off)

# %%
a=df3["Price"]

# %%
df4["Price"]
# Out:
# 1    10499
# Name: Price, dtype: int64

# %% [markdown]
# Conclusion:
# Flipkart is expensive than amazon
